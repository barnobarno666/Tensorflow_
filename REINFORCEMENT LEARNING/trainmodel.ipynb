# %% [markdown]
# i dont know

# %%
from snakeenv import SnakeEnv

from stable_baselines3 import PPO
import os

import time



models_dir = f"models/{int(time.time())}/"
logdir = f"logs/{int(time.time())}/"

if not os.path.exists(models_dir):
 os.makedirs(models_dir)

if not os.path.exists(logdir):
 os.makedirs(logdir)

env = SnakeEnv()
env.reset()

model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=logdir)

TIMESTEPS = 10
iters = 0
while True:
 iters += 1
 model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=f"PPO")
 model.save(f"{models_dir}/{TIMESTEPS*iters}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs/1689611118/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.23     |
# |    ep_rew_mean     | -1e+04   |
# | time/              |          |
# |    fps             | 15       |
# |    iterations      | 1        |
# |    time_elapsed    | 128      |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs/1689611118/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.7      |
# |    ep_rew_mean     | -1e+04   |
# | time/              |          |
# |    fps             | 16       |
# |    iterations      | 1        |
# |    time_elapsed    | 127      |
# |    total_timesteps | 4096     |
# ---------------------------------
# Logging to logs/1689611118/PPO_0
# ---------------------------------
# | rollout/           |          |
# ...

# %%
from snakeenv import SnakeEnv
env = SnakeEnv()
from stable_baselines3 import PPO, A2C, DQN
from stable_baselines3.common.env_util import make_vec_env
import gymnasium as gym
# Instantiate th
import gym
from snakeenv import SnakeEnv # Import your custom environment class

# Register your custom environment with gym
gym.envs.register(
    id='Snake-v0', # A unique id for your environment
    entry_point='snakeenv:SnakeEnv', # The module name and the class name of your environment
    max_episode_steps=1000, # The maximum number of steps per episode (optional)
    kwargs={} # Any keyword arguments to pass to your environment class (optional)
)
# Out:
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gym\envs\registration.py:498: UserWarning: WARN: Overriding environment Snake-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
# Create an instance of your environment
env = gym.make("Snake-v0")
# Loop for 10 episodes
for i in range(10):
    # Reset the environment and get the initial observation
    obs = env.reset()
    # Loop until done signal is received
    done = False
    while not done:
        # Choose an action using the model's prediction
        action, _states = model.predict(obs)
        # Take a step in the environment and get the next observation, reward, done signal, and info dictionary
        obs, reward, done, turn, info = env.step(action)
        # Render the environment in human mode
        env.render(mode='human')
# Close the environment and release any resources
env.close()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\Users\defaultuser0.LAPTOP-LRB3T941\Documents\Tensorflow\REINFORCEMENT LEARNING\trainmodel.ipynb Cell 4 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/defaultuser0.LAPTOP-LRB3T941/Documents/Tensorflow/REINFORCEMENT%20LEARNING/trainmodel.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # Create an instance of your environment
# ----> <a href='vscode-notebook-cell:/c%3A/Users/defaultuser0.LAPTOP-LRB3T941/Documents/Tensorflow/REINFORCEMENT%20LEARNING/trainmodel.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> env = gym.make("Snake-v0")
#       <a href='vscode-notebook-cell:/c%3A/Users/defaultuser0.LAPTOP-LRB3T941/Documents/Tensorflow/REINFORCEMENT%20LEARNING/trainmodel.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> # Loop for 10 episodes
# ...
