# %%
import pandas as pd
data=pd.read_csv('ffff.csv')
dta=pd.read_csv('sample_submission.csv')

# %%
print((data['Transported'][1]))



print(type(dta['Transported'][1]))
# Out:
# False
# <class 'numpy.bool_'>

# %%
for i in range(len(data)):
    if data['Transported'][i]==True:
        data['Transported'][i]=True
    else:
        data['Transported'][i]=False
# Out:
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Temp\ipykernel_4660\1306378133.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Transported'][i]=True
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Temp\ipykernel_4660\1306378133.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Transported'][i]=False

# %%
data.to_csv('helloo.csv',index=False)

# %%
data=pd.read_csv('train.csv')
import seaborn as sns 
sns.pairplot(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\lib\histograms.py:351, in _unsigned_subtract(a, b)
#     350 try:
# --> 351     dt = signed_to_unsigned[dt.type]
#     352 except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\Users\defaultuser0.LAPTOP-LRB3T941\Documents\Tensorflow\KAGGLE COMPETITION\spaceship-titanic\1.ipynb Cell 5 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/defaultuser0.LAPTOP-LRB3T941/Documents/Tensorflow/KAGGLE%20COMPETITION/spaceship-titanic/1.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> data=pd.read_csv('train.csv')
# ...
