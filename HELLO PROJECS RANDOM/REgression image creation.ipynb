# %%
import urllib.request
import  imageio.v2

url = "https://wallpaperaccess.com/full/2113692.jpg"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36"}
req = urllib.request.Request(url, headers=headers)

try:
    with urllib.request.urlopen(req) as response:
        img_data = response.read()

    img = imageio.v2.imread(img_data)
    # Now you can work with the 'img' object as needed

except Exception as e:
    print("Error:", e)

import matplotlib.pyplot as plt
plt.imshow(img) # display the image array
plt.axis('off')  # Turn off axis labels and ticks
plt.grid(False)  # Turn off grid lines
plt.figure(figsize=(90,90))
plt.show() # show the plot

# %%
import requests
import imageio as io
url = "https://wallpaperaccess.com/full/2113692.jpg"
response = requests.get(url)
img = io.imread(response.content)
from skimage import io
url = "https://example.com/image.jpg"
img = io.imread(url)

plt.imshow(img) # display the image array
plt.show() # show the plot
# Out:
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Temp\ipykernel_7284\3735684050.py:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = io.imread(response.content)
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\socket.py:833, in create_connection(address, timeout, source_address)
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
#     834 # Break explicitly a reference cycle
#
# ...

# %%
import urllib.request
import imageio as io
url="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQzWjGbQZhy2u_F_eToaTuBWBpqSUQZJFzxbA&usqp=CAU"
req = urllib.request.urlopen(url)
img = io.imread(req.read())
plt.imshow(img) # display the image array
plt.show() # show the plot
# Out:
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Temp\ipykernel_10500\2808533865.py:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = io.imread(req.read())

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import cv2

# %%
import shutil
import os
folder=r"D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Corn"
file_list=os.listdir(folder)
image_list=[]
for file in file_list:
    if file.endswith(".jpg"):
        image_list.append(folder+"\\"+file)
        
        
        
print(image_list[0])
# Out:
# D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Corn\0_100.jpg

# %%
x=cv2.imread(image_list[0])

print(x.shape)
all_images=[]
for image in image_list:
    all_images.append(cv2.imread(image))
# Out:
# (100, 100, 3)

# %%
resized_images = []
for images in all_images:
    new_image=cv2.resize(images, (70, 70))
    resized_images.append(new_image)

# %%
import matplotlib.pyplot as plt # import the matplotlib library
plt.imshow(resized_images[50],) #cmap='gray') # display the image array with the gray color map

plt.show() # show the plot

# %%
#IMAGE 2
import shutil
import os
folder=r"D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Pineapple"


file_list2=os.listdir(folder)
image_list2=[]
for file in file_list2:
    if file.endswith(".jpg"):
        image_list2.append(folder+"\\"+file)
        
        
        
#print(image_list[0])
#x=cv2.imread(image_list[0])
all_images2=[]
#print(x.shape)
second_images2=[]
for image in image_list2:
    all_images2.append(cv2.imread(image))
    
resized_images2 = []
for images in all_images2:
    new_image=cv2.resize(images, (100, 100))
    resized_images2.append(new_image)

# %%
import matplotlib.pyplot as plt # import the matplotlib library
plt.imshow(resized_images2[50] ,cmap='gray') # display the image array with the gray color map

plt.show() # show the plot

# %%
model=tf.keras.models.Sequential([
    tf.keras.layers.Dense(1,input_shape=x.shape ),
    
    
    tf.keras.layers.Dense(units=60,activation='relu'),
    tf.keras.layers.Dense(units=70,activation='relu'),
    tf.keras.layers.Dense(units=50,activation='relu'),
    tf.keras.layers.Dense(units=10,activation='relu')
    
        
        
    ])
# Out:
#   Cell In [38], line 13
#     ])
#     ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '(' on line 10
