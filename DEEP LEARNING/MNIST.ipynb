# %%
import tensorflow

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# %%
Image=cv2.imread(r'C:\Users\defaultuser0.LAPTOP-LRB3T941\Documents\Tensorflow\DEEP LEARNING\0_100.jpg',cv2.IMREAD_UNCHANGED)

# %%
#for i in range(100):
    #x=str(random.ranint(1,10000))+'.png'    def mover(i):
        
        
        
        
    #plt.imshow(Image)
#plt.show()
   # plt.savefig('foo.png')

# %%
Image.size
print(Image)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
