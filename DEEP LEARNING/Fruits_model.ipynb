# %%
import tensorflow
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
# Out:
# []

# %%
#SO FORGET AOUT THAT ,LETS MAKE A DATAFRAME FROM ALL THE DATAS THAT I GOT 
path=r'D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training'
folders=os.listdir(path)



#for item in items:
#    X_train.append()
print(folders,len(folders))
""" 131 items """
# Out:
# ['Apple Braeburn', 'Apple Crimson Snow', 'Apple Golden 1', 'Apple Golden 2', 'Apple Golden 3', 'Apple Granny Smith', 'Apple Pink Lady', 'Apple Red 1', 'Apple Red 2', 'Apple Red 3', 'Apple Red Delicious', 'Apple Red Yellow 1', 'Apple Red Yellow 2', 'Apricot', 'Avocado', 'Avocado ripe', 'Banana', 'Banana Lady Finger', 'Banana Red', 'Beetroot', 'Blueberry', 'Cactus fruit', 'Cantaloupe 1', 'Cantaloupe 2', 'Carambula', 'Cauliflower', 'Cherry 1', 'Cherry 2', 'Cherry Rainier', 'Cherry Wax Black', 'Cherry Wax Red', 'Cherry Wax Yellow', 'Chestnut', 'Clementine', 'Cocos', 'Corn', 'Corn Husk', 'Cucumber Ripe', 'Cucumber Ripe 2', 'Dates', 'Eggplant', 'Fig', 'Ginger Root', 'Granadilla', 'Grape Blue', 'Grape Pink', 'Grape White', 'Grape White 2', 'Grape White 3', 'Grape White 4', 'Grapefruit Pink', 'Grapefruit White', 'Guava', 'Hazelnut', 'Huckleberry', 'Kaki', 'Kiwi', 'Kohlrabi', 'Kumquats', 'Lemon', 'Lemon Meyer', 'Limes', 'Lychee', 'Mandarine', 'Mango', 'Mango Red', 'Mangostan', 'Maracuja', 'Me
# ...

# %%
datas={}
min_len=1000
for folder in folders:
    folder_item=[]
    path = r'D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training'+f"\{folder}"
    print(path)
    items=os.listdir(path) 
    for item in items:
        item_path=path+f'\{item}'
        folder_item.append(cv2.imread(item_path))
        #folder_item.reshape(-1,1)
    my_array = np.asarray(folder_item[:297] ,dtype=object)
    my_array.reshape(-1,1)
    datas[folder]=my_array
    if min_len >len(my_array): 
        min_len=len(my_array)
        
print(min_len)
# Out:
# D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Apple Braeburn
# D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Apple Crimson Snow
# D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Apple Golden 1
# D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Apple Golden 2
# D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Apple Golden 3
# D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Apple Granny Smith
# D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Apple Pink Lady
# D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Apple Red 1
# D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Apple Red 2
# D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Apple Red 3
# D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Apple Red Delicious
# D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Apple Red Yellow 1
# D:\DATASET\FRuites\fruits-360_dataset\fruits-360\Training\Apple Red Yellow 2
# ...

# %%
suck={}
suck['fucl']='a'
#suck['fucl']
print(suck)
print(datas)
# Out:
# {'fucl': 'a'}
# {'Apple Braeburn': array([[[[255, 255, 254],
#          [255, 255, 254],
#          [255, 255, 254],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 254],
#          [255, 255, 254],
#          [255, 255, 254],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 254],
#          [255, 255, 254],
#          [255, 255, 254],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
# ...

# %%
data=pd.DataFrame.from_dict(data_d,orient='index')
print(data)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\defaultuser0.LAPTOP-LRB3T941\Documents\Tensorflow\DEEP LEARNING\Fruits_model.ipynb Cell 6 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/defaultuser0.LAPTOP-LRB3T941/Documents/Tensorflow/DEEP%20LEARNING/Fruits_model.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> data=pd.DataFrame.from_dict(data_d,orient='index')
#       <a href='vscode-notebook-cell:/c%3A/Users/defaultuser0.LAPTOP-LRB3T941/Documents/Tensorflow/DEEP%20LEARNING/Fruits_model.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> print(data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:1764, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1758     raise ValueError(
#    1759         f"Expected 'index', 'columns' or 'tight' for orient parameter. "
# ...

# %%
data_d= {k: v.flatten() for k, v in datas.items()}
